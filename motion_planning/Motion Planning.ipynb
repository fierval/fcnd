# %% [markdown]
# ### Motion Planning Project ###

# %%
from IPython.display import HTML, display_markdown

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
# %run -n motion_planning.py

# %%
conn = MavlinkConnection('tcp:127.0.0.1:5760', timeout=120)
drone = MotionPlanning(conn, graph_data='flygraph.gpickle')
time.sleep(1)

drone.start()
# Out:
# Logs\TLog.txt
# Preparing flight graph...
# Graph prepared in 0.417 sec
# Logs\NavLog.txt
# starting connection
# arming transition
# Searching for a path ...
# global home [-122.3975   37.7925    0.    ], position [-122.3974   37.7925    0.162 ], local position [ 0.1283  0.0157 -0.1622]
# Found a path.
# Found a path.
# Local Start and Goal:  (0.1221581562422216, 0.016822525532916188, -0.162) (595.5753790569529, 444.22938590847934, 10.988500879969074)
# Path length:  17
# Sending waypoints to simulator ...
# waypoint transition
# target position [21.7762 16.0045 14.9566  0.    ]
# local position [-0.2326  0.2935 -0.2404]
# waypoint transition
# target position [67.2221 76.564  18.8517  0.    ]
# local position [ 21.5562  15.7523 -15.4913]
# waypoint transition
# target position [102.6181 113.9378  16.0258   0.    ]
# local position [ 67.2348  76.4013 -18.8264]
# waypoint transition
# target position [163.8271 147.4697  16.0385   0.    ]
# local position [102.1141 113.4733 -16.0296]
# waypoint transition
# target position [186.6072 192.3948  18.0279   0.    ]
# local position [163.9413 147.4794 -16.0406]
# waypoint transition
# target position [266.583  275.3074  19.5103   0.    ]
# local position [186.9733 192.7032 -18.0296]
# waypoint transition
# target position [340.0186 379.0305  15.343    0.    ]
# local position [266.9173 275.8497 -19.5142]
# waypoint transition
# target position [374.5309 375.1844  19.4701   0.    ]
# local position [340.1218 379.4995 -15.342 ]
# waypoint transition
# target position [397.8856 375.5875  18.4643   0.    ]
# local position [373.7543 375.4804 -19.4533]
# waypoint transition
# target position [421.24   359.3041  18.6035   0.    ]
# local position [398.2319 375.7122 -18.4721]
# waypoint transition
# target position [459.5291 369.8111  19.6477   0.    ]
# local position [420.635  359.8458 -18.6043]
# waypoint transition
# target position [482.1671 327.2507  12.3381   0.    ]
# local position [458.9326 369.4757 -19.6659]
# waypoint transition
# target position [523.0653 321.0423  18.4381   0.    ]
# local position [481.7932 327.7363 -12.3207]
# waypoint transition
# target position [550.1729 360.5627  24.1237   0.    ]
# local position [522.8019 321.0285 -18.4441]
# waypoint transition
# target position [589.4077 397.6793  19.0548   0.    ]
# local position [550.0242 360.3611 -24.118 ]
# waypoint transition
# target position [595.5754 444.2294  10.9885   0.    ]
# local position [589.6287 397.7125 -19.0634]
# landing transition
# disarm transition
# manual transition
# Closing connection ...

# %% [markdown]
# ### Watch me Fly! ###
# Flying the above path

# %%
# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/JccKcmcnVCU?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/JccKcmcnVCU?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>

# %%
plt.rcParams['figure.figsize'] = 20, 20

# %% [markdown]
# ## Flight Parameters ##
# This is what the grid looks like from the flying altitude of 25 m

# %%
display_markdown("#### Minimal altitude: {}m ####".format(10), raw=True)
display_markdown("#### Target altitude: {}m ####\n #### Safety Distance: {}m #### ".format(TARGET_ALTITUDE, SAFETY_DISTANCE), raw=True)
# Out:
# #### Minimal altitude: 10m ####
# #### Target altitude: 25m ####
#  #### Safety Distance: 5m ####

# %% [markdown]
# ### Collision Grid ###

# %%
drone.get_current_grid()
grid = drone.grid
data = drone.data
visualize_grid(grid, data)

# %% [markdown]
# ### Graph of Available Points ###

# %%
graph = drone.graph
visualize_graph(grid, graph, list(graph), data)

# %% [markdown]
# ### Chosen Path ###

# %%
visualize_path(grid, drone.graph, data, drone.path, drone.start, drone.goal)
